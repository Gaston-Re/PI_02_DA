# %%
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\gasty\AppData\Local\Temp\ipykernel_12872\1685778526.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
df1 = pd.read_csv('df1_Acceso a Internet Fijo por rangos de velocidad de bajada y provincia.csv', dtype=str)
df3 = pd.read_csv('df3_Accesos a banda ancha y banda angosta por provincia.csv', dtype=str)
df6 = pd.read_csv('df6_Accesos a Internet fijo por velocidad de bajada y localidad.csv', dtype=str)
df7 = pd.read_csv('df7_Conectividad al servicio de Internet.csv')
df9 = pd.read_csv('df9_Ingresos trimestrales por la prestación del servicio de Internet fijo.csv')
df11 = pd.read_csv('df11_Penetración de Internet fijo (accesos por cada 100 hogares).csv')
df12 =pd.read_csv('df12_Listado de localidades con conectividad a internet..csv')
df13 = pd.read_csv('df13_Penetración por hogares nacional de Internet fijo.csv', dtype=str)
df15 = pd.read_csv('df15_Total nacional de accesos a Internet fijo por banda ancha y banda angosta.csv', dtype=str)
df17 = pd.read_csv('df17_Velocidad Media de bajada de Internet fijo.csv')

# %%
df2 = pd.read_excel('df2_Acceso a Internet fijo por tecnología y provincia.xlsx')
df4 = pd.read_excel('df4_Accesos a Internet fijo por tecnología y localidad.xlsx')
df8 = pd.read_excel('df8_.xlsx')
df10 = pd.read_excel('df10_Internet_Accesos-por-tecnologia.xlsx')

# %% [markdown]
# # ETL

# %% [markdown]
# ## Provincia

# %%
df2
# Out:
#      Año  Trimestre     ADSL  Cablemodem  Fibra óptica  Wireless   Otros  \
# 0   2022          3  1395277     6031970       2871541    557110  235230
# 1   2022          2  1468333     5979214       2723285    556243  231609
# 2   2022          1  1533240     6073426       2219533    545814  251996
# 3   2021          4  1657615     5984240       2072236    523107  252596
# 4   2021          3  1950631     5826257       1566048    492415  250190
# 5   2021          2  2018587     5641731       1472246    476968  253552
# 6   2021          1  2175211     5424782       1362976    434548  250455
# 7   2020          4  2213949     5371824       1311199    421554  253036
# 8   2020          3  2263889     5259351       1170879    413259  248821
# 9   2020          2  2295533     5005115       1106725    376667  247016
# 10  2020          1  2299457     4903674       1047817    352333  209145
# 11  2019          4  2414575     4883869        941295    340144  213298
# ...

# %%
columnas_df1 = ['Año', 'Trimestre', 'HASTA 512 kbps', '+ 512 Kbps - 1 Mbps', '+ 1 Mbps - 6 Mbps', '+ 6 Mbps - 10 Mbps', '+ 10 Mbps - 20 Mbps', '+ 20 Mbps - 30 Mbps', '+ 30 Mbps', 'OTROS', 'Total']

# %%
df1[columnas_df1] = df1[columnas_df1].fillna(0)

# %%
df1[columnas_df1] = df1[columnas_df1].astype(str)
df1[columnas_df1] = df1[columnas_df1].apply(lambda x: x.str.replace('.', '')).astype(int)

# %%
df1
# Out:
#       Año  Trimestre            Provincia  HASTA 512 kbps  \
# 0    2022          3         Buenos Aires           29985
# 1    2022          3      Capital Federal             517
# 2    2022          3            Catamarca              71
# 3    2022          3                Chaco             461
# 4    2022          3               Chubut             109
# ..    ...        ...                  ...             ...
# 835  2014          1           Santa Cruz             161
# 836  2014          1             Santa Fe            8456
# 837  2014          1  Santiago Del Estero            1234
# 838  2014          1     Tierra Del Fuego              12
# 839  2014          1              Tucumán               6
#
#      + 512 Kbps - 1 Mbps  + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  \
# 0                  27709             290315              297915
# 1                   5742              34371               67829
# 2                    384               3107                5389
# ...

# %%
columnas_df3 = ['Año', 'Trimestre', 'Banda ancha fija', 'Dial up', 'Total']
df3[columnas_df3] = df3[columnas_df3].fillna(0)

# %%
df3[columnas_df3] = df3[columnas_df3].astype(str)
caracteres_no_numericos = ['.', '-', ' ']
for col in columnas_df3:
    for caracter in caracteres_no_numericos:
        df3[col] = df3[col].str.replace(caracter, '')
    df3[col] = df3[col].astype(int)

# %%
df3
# Out:
#       Año  Trimestre            Provincia  Banda ancha fija  Dial up    Total
# 0    2022          3         Buenos Aires           4715469     6199  4721668
# 1    2022          3      Capital Federal           1545534     2145  1547679
# 2    2022          3            Catamarca             70292        1    70293
# 3    2022          3                Chaco            144141        5   144146
# 4    2022          3               Chubut            164874      904   165778
# ..    ...        ...                  ...               ...      ...      ...
# 835  2014          1           Santa Cruz             26304      460    26764
# 836  2014          1             Santa Fe            506000      612   506612
# 837  2014          1  Santiago Del Estero             37124        9    37133
# 838  2014          1     Tierra Del Fuego             27272      766    28038
# 839  2014          1              Tucumán            129944       88   130032
#
# [840 rows x 6 columns]

# %%
df11
# Out:
#       Año  Trimestre            Provincia Accesos por cada 100 hogares
# 0    2022          3         Buenos Aires                        78,11
# 1    2022          3      Capital Federal                       122,28
# 2    2022          3            Catamarca                        65,33
# 3    2022          3                Chaco                        43,86
# 4    2022          3               Chubut                        84,38
# ..    ...        ...                  ...                          ...
# 835  2014          1           Santa Cruz                        28,94
# 836  2014          1             Santa Fe                        47,85
# 837  2014          1  Santiago Del Estero                        16,31
# 838  2014          1     Tierra Del Fuego                        63,97
# 839  2014          1              Tucumán                        33,42
#
# [840 rows x 4 columns]

# %%
df1.insert(11, 'Banda ancha fija', df3['Banda ancha fija'])
df1.insert(12, 'Dial up', df3['Dial up'])

# %%
df1['Accesos por cada 100 hogares'] = df11['Accesos por cada 100 hogares'].apply(lambda x: x.replace(',', '.')).astype(float)

# %%
df1
# Out:
#       Año  Trimestre            Provincia  HASTA 512 kbps  \
# 0    2022          3         Buenos Aires           29985
# 1    2022          3      Capital Federal             517
# 2    2022          3            Catamarca              71
# 3    2022          3                Chaco             461
# 4    2022          3               Chubut             109
# ..    ...        ...                  ...             ...
# 835  2014          1           Santa Cruz             161
# 836  2014          1             Santa Fe            8456
# 837  2014          1  Santiago Del Estero            1234
# 838  2014          1     Tierra Del Fuego              12
# 839  2014          1              Tucumán               6
#
#      + 512 Kbps - 1 Mbps  + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  \
# 0                  27709             290315              297915
# 1                   5742              34371               67829
# 2                    384               3107                5389
# ...

# %%
df1.dtypes
# Out:
# Año                               int32
# Trimestre                         int32
# Provincia                        object
# HASTA 512 kbps                    int32
# + 512 Kbps - 1 Mbps               int32
# + 1 Mbps - 6 Mbps                 int32
# + 6 Mbps - 10 Mbps                int32
# + 10 Mbps - 20 Mbps               int32
# + 20 Mbps - 30 Mbps               int32
# + 30 Mbps                         int32
# OTROS                             int32
# Banda ancha fija                  int32
# Dial up                           int32
# Total                             int32
# Accesos por cada 100 hogares    float64
# dtype: object

# %% [markdown]
# ## Localidad

# %%
df4
# Out:
#          Provincia      Partido                           Localidad  \
# 0     BUENOS AIRES   25 de Mayo                          25 de Mayo
# 1     BUENOS AIRES   25 de Mayo                           Del Valle
# 2     BUENOS AIRES   25 de Mayo                   Gobernador Ugarte
# 3     BUENOS AIRES   25 de Mayo              Norberto de la Riestra
# 4     BUENOS AIRES   25 de Mayo                    Lucas Monteverde
# ...            ...          ...                                 ...
# 3137       TUCUMAN   Tafí Viejo  Villa Mariano Moreno - El Colmenar
# 3138       TUCUMAN      Trancas                San Pedro de Colalao
# 3139       TUCUMAN      Trancas                   Villa  de Trancas
# 3140       TUCUMAN  Yerba Buena                       Villa Carmela
# 3141       TUCUMAN  Yerba Buena            Yerba Buena - Marcos Paz
#
#      Link Indec  ADSL  CABLEMODEM  DIAL UP  FIBRA OPTICA  OTROS  SATELITAL  \
# ...

# %%
df4.dtypes
# Out:
# Provincia        object
# Partido          object
# Localidad        object
# Link Indec       object
# ADSL              int64
# CABLEMODEM        int64
# DIAL UP           int64
# FIBRA OPTICA      int64
# OTROS             int64
# SATELITAL         int64
# WIMAX             int64
# WIRELESS          int64
# Total general     int64
# dtype: object

# %%
print(df6.columns)
# Out:
# Index(['Provincia', 'Partido', 'Localidad', 'Link Indec', 'Otros',
#        '0,256 mbps', '0,375 mbps', '0,5 mbps', '0,512 mbps', '0,625 mbps',
#        '0,75 mbps', '1 mbps', '1,25 mbps', '1,5 mbps', '2 mbps', '2,2 mbps',
#        '2,5 mbps', '3 mbps', '3,3 mbps', '3,5 mbps', '4 mbps', '4,5 mbps',
#        '5 mbps', '6 mbps', '6,4 mbps', '7 mbps', '7,5 mbps', '8 mbps',
#        '9 mbps', '10 mbps', '11 mbps', '12 mbps', '13 mbps', '14 mbps',
#        '15 mbps', '16 mbps', '17 mbps', '18 mbps', '19 mbps', '20 mbps',
#        '21 mbps', '22 mbps', '23 mbps', '24 mbps', '25 mbps', '25,1 mbps',
#        '25,11 mbps', '25,5 mbps', '26 mbps', '30 mbps', '31 mbps', '32 mbps',
#        '34 mbps', '35 mbps', '36 mbps', '38 mbps', '39 mbps', '40 mbps',
#        '41 mbps', '45 mbps', '46 mbps', '49 mbps', '50 mbps', '55 mbps',
#        '58 mbps', '59 mbps', '60 mbps', '61 mbps', '62 mbps', '64 mbps',
#        '65 mbps', '66 mbps', '70 mbps', '75 mbps', '78 mbps', '80 mbps',
# ...

# %%
columnas_df6 = ['Otros',
       '0,256 mbps', '0,375 mbps', '0,5 mbps', '0,512 mbps', '0,625 mbps',
       '0,75 mbps', '1 mbps', '1,25 mbps', '1,5 mbps', '2 mbps', '2,2 mbps',
       '2,5 mbps', '3 mbps', '3,3 mbps', '3,5 mbps', '4 mbps', '4,5 mbps',
       '5 mbps', '6 mbps', '6,4 mbps', '7 mbps', '7,5 mbps', '8 mbps',
       '9 mbps', '10 mbps', '11 mbps', '12 mbps', '13 mbps', '14 mbps',
       '15 mbps', '16 mbps', '17 mbps', '18 mbps', '19 mbps', '20 mbps',
       '21 mbps', '22 mbps', '23 mbps', '24 mbps', '25 mbps', '25,1 mbps',
       '25,11 mbps', '25,5 mbps', '26 mbps', '30 mbps', '31 mbps', '32 mbps',
       '34 mbps', '35 mbps', '36 mbps', '38 mbps', '39 mbps', '40 mbps',
       '41 mbps', '45 mbps', '46 mbps', '49 mbps', '50 mbps', '55 mbps',
       '58 mbps', '59 mbps', '60 mbps', '61 mbps', '62 mbps', '64 mbps',
       '65 mbps', '66 mbps', '70 mbps', '75 mbps', '78 mbps', '80 mbps',
       '82 mbps', '83 mbps', '85 mbps', '90 mbps', '92 mbps', '95 mbps',
       '100 mbps']
df6[columnas_df6] = df6[columnas_df6].fillna(0)

# %%
df6[columnas_df6] = df6[columnas_df6].astype(str)
df6[columnas_df6] = df6[columnas_df6].apply(lambda x: x.str.replace('.', '').str.replace(',', '')).astype(int)

# %%
# Sumar columnas específicas y guardar el resultado en una nueva columna
df6['HASTA 512 kbps'] = df6[['Otros',
       '0,256 mbps', '0,375 mbps', '0,5 mbps', '0,512 mbps']].sum(axis=1)
df6['+ 512 Kbps - 2 Mbps'] = df6[['0,625 mbps',
       '0,75 mbps', '1 mbps', '1,25 mbps', '1,5 mbps', '2 mbps']].sum(axis=1)
df6['+ 2 Kbps - 6 Mbps'] = df6[['2,2 mbps',
       '2,5 mbps', '3 mbps', '3,3 mbps', '3,5 mbps', '4 mbps', '4,5 mbps',
       '5 mbps', '6 mbps']].sum(axis=1)
df6['+ 6 Kbps - 13 Mbps'] = df6[['6,4 mbps', '7 mbps', '7,5 mbps', '8 mbps',
       '9 mbps', '10 mbps', '11 mbps', '12 mbps', '13 mbps']].sum(axis=1)
df6['+ 13 Kbps - 20 Mbps'] = df6[['14 mbps',
       '15 mbps', '16 mbps', '17 mbps', '18 mbps', '19 mbps', '20 mbps']].sum(axis=1)
df6['+ 20 Kbps - 40 Mbps'] = df6[['21 mbps', '22 mbps', '23 mbps', '24 mbps', '25 mbps', '25,1 mbps',
       '25,11 mbps', '25,5 mbps', '26 mbps', '30 mbps', '31 mbps', '32 mbps',
       '34 mbps', '35 mbps', '36 mbps', '38 mbps', '39 mbps', '40 mbps']].sum(axis=1)
df6['+ 40 Kbps - 60 Mbps'] = df6[['41 mbps', '45 mbps', '46 mbps', '49 mbps', '50 mbps', '55 mbps',
       '58 mbps', '59 mbps', '60 mbps']].sum(axis=1)
df6['+ 60 Kbps - 80 Mbps'] = df6[['61 mbps', '62 mbps', '64 mbps',
       '65 mbps', '66 mbps', '70 mbps', '75 mbps', '78 mbps', '80 mbps']].sum(axis=1)
df6['+ 80 Kbps - 100 Mbps'] = df6[['82 mbps', '83 mbps', '85 mbps', '90 mbps', '92 mbps', '95 mbps',
       '100 mbps']].sum(axis=1)
# Eliminar las columnas originales
df6 = df6.drop(columns=columnas_df6)

# %%
df6['Total'] = df6[['HASTA 512 kbps', '+ 512 Kbps - 2 Mbps', '+ 2 Kbps - 6 Mbps', '+ 6 Kbps - 13 Mbps', '+ 13 Kbps - 20 Mbps', '+ 20 Kbps - 40 Mbps', '+ 40 Kbps - 60 Mbps', '+ 60 Kbps - 80 Mbps', '+ 80 Kbps - 100 Mbps']].sum(axis=1)

# %%
df6
# Out:
#          Provincia      Partido                           Localidad  \
# 0     BUENOS AIRES   25 de Mayo                          25 de Mayo
# 1     BUENOS AIRES   25 de Mayo                     Agustín Mosconi
# 2     BUENOS AIRES   25 de Mayo                           Del Valle
# 3     BUENOS AIRES   25 de Mayo                           Ernestina
# 4     BUENOS AIRES   25 de Mayo                   Gobernador Ugarte
# ...            ...          ...                                 ...
# 3093       TUCUMAN   Tafí Viejo  Villa Mariano Moreno - El Colmenar
# 3094       TUCUMAN      Trancas                San Pedro de Colalao
# 3095       TUCUMAN      Trancas                   Villa  de Trancas
# 3096       TUCUMAN  Yerba Buena                       Villa Carmela
# 3097       TUCUMAN  Yerba Buena            Yerba Buena - Marcos Paz
#
#      Link Indec  HASTA 512 kbps  + 512 Kbps - 2 Mbps  + 2 Kbps - 6 Mbps  \
# 0       6854100               2                   19                403
# ...

# %%
df6.dtypes
# Out:
# Provincia               object
# Partido                 object
# Localidad               object
# Link Indec              object
# HASTA 512 kbps           int64
# + 512 Kbps - 2 Mbps      int64
# + 2 Kbps - 6 Mbps        int64
# + 6 Kbps - 13 Mbps       int64
# + 13 Kbps - 20 Mbps      int64
# + 20 Kbps - 40 Mbps      int64
# + 40 Kbps - 60 Mbps      int64
# + 60 Kbps - 80 Mbps      int64
# + 80 Kbps - 100 Mbps     int64
# Total                    int64
# dtype: object

# %% [markdown]
# el df12 y df 7 hablan de lo mismo, df7 muestra poblacion

# %%
df12
# Out:
#          Provincia       Partido        Localidad ADSL CABLEMODEM DIALUP  \
# 0     BUENOS AIRES  Bahía Blanca    Villa Bordeau   --         --     --
# 1     BUENOS AIRES  Bahía Blanca     Villa Espora   --         --     --
# 2     BUENOS AIRES      Balcarce         Balcarce   SI         SI     SI
# 3     BUENOS AIRES      Balcarce        Los Pinos   --         --     --
# 4     BUENOS AIRES      Balcarce        Napaleofú   --         --     --
# ...            ...           ...              ...  ...        ...    ...
# 4307         CHACO     Quitilipi        Quitilipi   SI         --     --
# 4308         CHACO     Quitilipi  Villa El Palmar   --         --     --
# 4309         CHACO  San Fernando     Barranqueras   SI         SI     --
# 4310         CHACO  San Fernando           Basail   SI         SI     --
# 4311         CHACO  San Fernando  Colonia Baranda   --         --     --
#
#      FIBRAOPTICA  4G  3G TELEFONIAFIJA WIRELESS SATELITAL
# ...

# %%
df7
# Out:
#          Provincia       Partido        Localidad  Poblacion ADSL CABLEMODEM  \
# 0     BUENOS AIRES  Bahía Blanca    Villa Bordeau          0   --         --
# 1     BUENOS AIRES  Bahía Blanca     Villa Espora          0   --         --
# 2     BUENOS AIRES      Balcarce         Balcarce      38376   SI         SI
# 3     BUENOS AIRES      Balcarce        Los Pinos        337   --         --
# 4     BUENOS AIRES      Balcarce        Napaleofú        374   --         --
# ...            ...           ...              ...        ...  ...        ...
# 4307         CHACO     Quitilipi        Quitilipi      24517   SI         --
# 4308         CHACO     Quitilipi  Villa El Palmar        879   --         --
# 4309         CHACO  San Fernando     Barranqueras      54698   SI         SI
# 4310         CHACO  San Fernando           Basail       1929   SI         SI
# 4311         CHACO  San Fernando  Colonia Baranda        336   --         --
#
# ...

# %% [markdown]
# ## Nacionales

# %%
df9['Ingresos (miles de pesos)'] = df9['Ingresos (miles de pesos)'].apply(lambda x: x.replace('.', '')).astype(int)

# %%
df9
# Out:
#      Año  Trimestre  Ingresos (miles de pesos)        Periodo
# 0   2022          3                   67055930  Jul-Sept 2022
# 1   2022          2                   60335724   Abr-Jun 2022
# 2   2022          1                   55589997   Ene-Mar 2022
# 3   2021          4                   45467887   Oct-Dic 2021
# 4   2021          3                   42999944  Jul-Sept 2021
# 5   2021          2                   38239667   Abr-Jun 2021
# 6   2021          1                   36676371   Ene-Mar 2021
# 7   2020          4                   33539703   Oct-Dic 2020
# 8   2020          3                   31997445  Jul-Sept 2020
# 9   2020          2                   32102476   Abr-Jun 2020
# 10  2020          1                   29946216   Ene-Mar 2020
# 11  2019          4                   24169251   Oct-Dic 2019
# 12  2019          3                   21652748  Jul-Sept 2019
# 13  2019          2                   20743118   Abr-Jun 2019
# ...

# %%
df9.dtypes
# Out:
# Año                           int64
# Trimestre                     int64
# Ingresos (miles de pesos)     int32
# Periodo                      object
# dtype: object

# %%
df17['Mbps (Media de bajada)'] = df17['Mbps (Media de bajada)'].apply(lambda x: x.replace(',', '.')).astype(float)

# %%
df17.dtypes
# Out:
# Año                         int64
# Trimestre                   int64
# Mbps (Media de bajada)    float64
# Trimestre.1                object
# dtype: object

# %%
columnas_df15 = ['Banda ancha fija', 'Dial up', 'Total']

# %%
df15[columnas_df15] = df15[columnas_df15].apply(lambda x: x.str.replace('.', '')).astype(int)

# %%
df15.dtypes
# Out:
# Año                 object
# Trimestre           object
# Banda ancha fija     int32
# Dial up              int32
# Total                int32
# Periodo             object
# dtype: object

# %%
df15
# Out:
#      Año Trimestre  Banda ancha fija  Dial up     Total        Periodo
# 0   2022         3          11078691    12437  11091128  Jul-Sept 2022
# 1   2022         2          10946248    12436  10958684   Abr-Jun 2022
# 2   2022         1          10611390    12619  10624009   Ene-Mar 2022
# 3   2021         4          10476933    12861  10489794   Oct-Dic 2021
# 4   2021         3          10075184    10357  10085541  Jul-Sept 2021
# 5   2021         2           9852702    10382   9863084   Abr-Jun 2021
# 6   2021         1           9637956    10016   9647972   Ene-Mar 2021
# 7   2020         4           9561546    10016   9571562   Oct-Dic 2020
# 8   2020         3           9346183    10016   9356199  Jul-Sept 2020
# 9   2020         2           9021040    10016   9031056   Abr-Jun 2020
# 10  2020         1           8802435     9991   8812426   Ene-Mar 2020
# 11  2019         4           8783053    10128   8793181   Oct-Dic 2019
# ...

# %%
columnas_df13 = ['Accesos por cada 100 hogares', 'Accesos por cada 100 hab']

# %%
df13[columnas_df13] = df13[columnas_df13].apply(lambda x: x.str.replace(',', '.')).astype(float)

# %%
df13.dtypes
# Out:
# Año                              object
# Trimestre                        object
# Accesos por cada 100 hogares    float64
# Accesos por cada 100 hab        float64
# Periodo                          object
# dtype: object

# %%
df13
# Out:
#      Año Trimestre  Accesos por cada 100 hogares  Accesos por cada 100 hab  \
# 0   2022         3                         76.64                     23.95
# 1   2022         2                         75.97                     23.72
# 2   2022         1                         73.88                     23.05
# 3   2021         4                         73.18                     22.81
# 4   2021         3                         70.58                     21.98
# 5   2021         2                         69.24                     21.55
# 6   2021         1                         67.95                     21.13
# 7   2020         4                         67.62                     21.01
# 8   2020         3                         66.31                     20.59
# 9   2020         2                         64.21                     19.92
# 10  2020         1                         62.86                     19.48
# ...

# %%
df10
# Out:
#      Año  Trimestre     ADSL  Cablemodem  Fibra óptica  Wireless   Otros  \
# 0   2022          3  1395277     6031970       2871541    557110  235230
# 1   2022          2  1468333     5979214       2723285    556243  231609
# 2   2022          1  1533240     6073426       2219533    545814  251996
# 3   2021          4  1657615     5984240       2072236    523107  252596
# 4   2021          3  1950631     5826257       1566048    492415  250190
# 5   2021          2  2018587     5641731       1472246    476968  253552
# 6   2021          1  2175211     5424782       1362976    434548  250455
# 7   2020          4  2213949     5371824       1311199    421554  253036
# 8   2020          3  2263889     5259351       1170879    413259  248821
# 9   2020          2  2295533     5005115       1106725    376667  247016
# 10  2020          1  2299457     4903674       1047817    352333  209145
# 11  2019          4  2414575     4883869        941295    340144  213298
# ...

# %%
df10['Mbps (Media de bajada)'] = df17['Mbps (Media de bajada)']
df10[columnas_df15] = df15[columnas_df15]
df10[columnas_df13] = df13[columnas_df13]
df10['Ingresos (miles de pesos)'] = df9['Ingresos (miles de pesos)']

# %%
df10.columns
# Out:
# Index(['Año', 'Trimestre', 'ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless',
#        'Otros', 'Total', 'Periodo', 'Mbps (Media de bajada)',
#        'Banda ancha fija', 'Dial up', 'Accesos por cada 100 hogares',
#        'Accesos por cada 100 hab', 'Ingresos (miles de pesos)'],
#       dtype='object')

# %%
df10 = df10[['Año', 'Periodo', 'Trimestre', 'ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless',
       'Otros', 'Banda ancha fija', 'Dial up', 'Total', 'Mbps (Media de bajada)', 'Accesos por cada 100 hogares',
       'Accesos por cada 100 hab', 'Ingresos (miles de pesos)']]

# %%
df10
# Out:
#      Año        Periodo  Trimestre     ADSL  Cablemodem  Fibra óptica  \
# 0   2022  Jul-Sept 2022          3  1395277     6031970       2871541
# 1   2022   Abr-Jun 2022          2  1468333     5979214       2723285
# 2   2022   Ene-Mar 2022          1  1533240     6073426       2219533
# 3   2021   Oct-Dic 2021          4  1657615     5984240       2072236
# 4   2021  Jul-Sept 2021          3  1950631     5826257       1566048
# 5   2021   Abr-Jun 2021          2  2018587     5641731       1472246
# 6   2021   Ene-Mar 2021          1  2175211     5424782       1362976
# 7   2020   Oct-Dic 2020          4  2213949     5371824       1311199
# 8   2020  Jul-Sept 2020          3  2263889     5259351       1170879
# 9   2020   Abr-Jun 2020          2  2295533     5005115       1106725
# 10  2020   Ene-Mar 2020          1  2299457     4903674       1047817
# 11  2019   Oct-Dic 2019          4  2414575     4883869        941295
# ...

# %%
df10.dtypes
# Out:
# Año                               int64
# Periodo                          object
# Trimestre                         int64
# ADSL                              int64
# Cablemodem                        int64
# Fibra óptica                      int64
# Wireless                          int64
# Otros                             int64
# Banda ancha fija                  int32
# Dial up                           int32
# Total                             int32
# Mbps (Media de bajada)          float64
# Accesos por cada 100 hogares    float64
# Accesos por cada 100 hab        float64
# Ingresos (miles de pesos)         int32
# dtype: object

# %%
df8
# Out:
#      Año  Trimestre  Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  \
# 0   2022          3           33013                    96727
# 1   2022          2           33667                    99498
# 2   2022          1           34890                   104840
# 3   2021          4           41262                    28521
# 4   2021          3           40174                    41437
# 5   2021          2           40172                    42024
# 6   2021          1           39487                    41674
# 7   2020          4           39510                    42185
# 8   2020          3           41038                    44005
# 9   2020          2           41038                    48690
# 10  2020          1           42550                    56170
# 11  2019          4           38272                    28980
# 12  2019          3          241713                    80599
# 13  2019          2          202790                    95980
# ...

# %%
df8.dtypes
# Out:
# Año                        int64
# Trimestre                  int64
# Hasta 512 kbps             int64
# Entre 512 Kbps y 1 Mbps    int64
# Entre 1 Mbps y 6 Mbps      int64
# Entre 6 Mbps y 10 Mbps     int64
# Entre 10 Mbps y 20 Mbps    int64
# Entre 20 Mbps y 30 Mbps    int64
# Más de 30 Mbps             int64
# OTROS                      int64
# Total                      int64
# dtype: object

# %%
#df10.to_csv('Nacional.csv', index=False)
#df8.to_csv('Nacional_rangos.csv', index=False)

# %%
#df1.to_csv('Acceso Internet Provincias.csv', index=False)

# %%
#df6.to_csv('Acceso Internet Rangos Provincia.csv', index=False)
#df7.to_csv('Acceso Internet Tecnologia.csv', index=False)
#df4.to_csv('Acceso Internet Tecnologia Cantidad.csv', index=False)

# %% [markdown]
# # EDA

# %%
def grafico_correlacion_mapadecalor(df):
    numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
    numeric_df = df[numeric_columns]
    correlation_matrix = numeric_df.corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
    plt.title('Matriz de correlación')
    plt.show()

# %% [markdown]
# ## Nacional

# %%
print(df10.shape)
df10.head()
# Out:
# (35, 15)
#     Año        Periodo  Trimestre     ADSL  Cablemodem  Fibra óptica  \
# 0  2022  Jul-Sept 2022          3  1395277     6031970       2871541
# 1  2022   Abr-Jun 2022          2  1468333     5979214       2723285
# 2  2022   Ene-Mar 2022          1  1533240     6073426       2219533
# 3  2021   Oct-Dic 2021          4  1657615     5984240       2072236
# 4  2021  Jul-Sept 2021          3  1950631     5826257       1566048
#
#    Wireless   Otros  Banda ancha fija  Dial up     Total  \
# 0    557110  235230          11078691    12437  11091128
# 1    556243  231609          10946248    12436  10958684
# 2    545814  251996          10611390    12619  10624009
# 3    523107  252596          10476933    12861  10489794
# 4    492415  250190          10075184    10357  10085541
#
#    Mbps (Media de bajada)  Accesos por cada 100 hogares  \
# 0                   62.46                         76.64
# 1                   58.44                         75.97
# ...

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           35 non-null     int64
#  1   Periodo                       35 non-null     object
#  2   Trimestre                     35 non-null     int64
#  3   ADSL                          35 non-null     int64
#  4   Cablemodem                    35 non-null     int64
#  5   Fibra óptica                  35 non-null     int64
#  6   Wireless                      35 non-null     int64
#  7   Otros                         35 non-null     int64
#  8   Banda ancha fija              35 non-null     int32
#  9   Dial up                       35 non-null     int32
#  10  Total                         35 non-null     int32
#  11  Mbps (Media de bajada)        35 non-null     float64
#  12  Accesos por cada 100 hogares  35 non-null     float64
# ...

# %%
df10.describe()
# Out:
#                Año  Trimestre          ADSL    Cablemodem  Fibra óptica  \
# count    35.000000  35.000000  3.500000e+01  3.500000e+01  3.500000e+01
# mean   2017.885714   2.457143  3.040425e+06  4.122601e+06  7.390627e+05
# std       2.564135   1.120474  8.354122e+05  1.225277e+06  7.861772e+05
# min    2014.000000   1.000000  1.395277e+06  2.407330e+06  1.391870e+05
# 25%    2016.000000   1.500000  2.279711e+06  2.966749e+06  1.679880e+05
# 50%    2018.000000   2.000000  3.557216e+06  4.038141e+06  2.262850e+05
# 75%    2020.000000   3.000000  3.723156e+06  5.132233e+06  1.138802e+06
# max    2022.000000   4.000000  3.803024e+06  6.073426e+06  2.871541e+06
#
#             Wireless          Otros  Banda ancha fija       Dial up  \
# count      35.000000      35.000000      3.500000e+01     35.000000
# mean   248280.028571  147431.085714      8.274417e+06  23383.371429
# std    174354.292929   85868.716764      1.408774e+06  10087.397193
# ...

# %%
tipo_texto_df10 = df10.select_dtypes(include=["object"]).columns
data_texto_df10 = df10[tipo_texto_df10]
data_texto_df10.describe()
# Out:
#               Periodo
# count              35
# unique             35
# top     Jul-Sept 2022
# freq                1

# %%
df10.isnull().sum()
# Out:
# Año                             0
# Periodo                         0
# Trimestre                       0
# ADSL                            0
# Cablemodem                      0
# Fibra óptica                    0
# Wireless                        0
# Otros                           0
# Banda ancha fija                0
# Dial up                         0
# Total                           0
# Mbps (Media de bajada)          0
# Accesos por cada 100 hogares    0
# Accesos por cada 100 hab        0
# Ingresos (miles de pesos)       0
# dtype: int64

# %%
print(df8.shape)
df8.head()
# Out:
# (35, 11)
#     Año  Trimestre  Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  \
# 0  2022          3           33013                    96727
# 1  2022          2           33667                    99498
# 2  2022          1           34890                   104840
# 3  2021          4           41262                    28521
# 4  2021          3           40174                    41437
#
#    Entre 1 Mbps y 6 Mbps  Entre 6 Mbps y 10 Mbps  Entre 10 Mbps y 20 Mbps  \
# 0                1161370                 1151906                   823505
# 1                1193090                 1197030                   856562
# 2                1263273                 1209148                   967508
# 3                1413208                 1245333                   976539
# 4                2550229                 1095772                   710122
#
#    Entre 20 Mbps y 30 Mbps  Más de 30 Mbps   OTROS     Total
# 0                   479822         6995750  349035  11091128
# ...

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Año                      35 non-null     int64
#  1   Trimestre                35 non-null     int64
#  2   Hasta 512 kbps           35 non-null     int64
#  3   Entre 512 Kbps y 1 Mbps  35 non-null     int64
#  4   Entre 1 Mbps y 6 Mbps    35 non-null     int64
#  5   Entre 6 Mbps y 10 Mbps   35 non-null     int64
#  6   Entre 10 Mbps y 20 Mbps  35 non-null     int64
#  7   Entre 20 Mbps y 30 Mbps  35 non-null     int64
#  8   Más de 30 Mbps           35 non-null     int64
#  9   OTROS                    35 non-null     int64
#  10  Total                    35 non-null     int64
# dtypes: int64(11)
# memory usage: 3.1 KB

# %%
df8.describe()
# Out:
#                Año  Trimestre  Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  \
# count    35.000000  35.000000       35.000000                35.000000
# mean   2017.885714   2.457143    50074.228571            243428.314286
# std       2.564135   1.120474    53083.966405            199321.891143
# min    2014.000000   1.000000     5675.000000             28521.000000
# 25%    2016.000000   1.500000    26397.000000             68384.500000
# 50%    2018.000000   2.000000    39487.000000            217997.000000
# 75%    2020.000000   3.000000    41210.000000            394515.500000
# max    2022.000000   4.000000   241713.000000            687619.000000
#
#        Entre 1 Mbps y 6 Mbps  Entre 6 Mbps y 10 Mbps  Entre 10 Mbps y 20 Mbps  \
# count           3.500000e+01            3.500000e+01             3.500000e+01
# mean            3.623279e+06            8.975174e+05             9.190145e+05
# std             1.292407e+06            2.462911e+05             4.881587e+05
# ...

# %%
df8.isnull().sum()
# Out:
# Año                        0
# Trimestre                  0
# Hasta 512 kbps             0
# Entre 512 Kbps y 1 Mbps    0
# Entre 1 Mbps y 6 Mbps      0
# Entre 6 Mbps y 10 Mbps     0
# Entre 10 Mbps y 20 Mbps    0
# Entre 20 Mbps y 30 Mbps    0
# Más de 30 Mbps             0
# OTROS                      0
# Total                      0
# dtype: int64

# %%
grafico_correlacion_mapadecalor(df10)

# %%
df10.hist(bins = 50, figsize= (20,15))
plt.show()

# %%
grafico_correlacion_mapadecalor(df8)

# %%
df8.hist(bins = 50, figsize= (20,15))
plt.show()

# %% [markdown]
# ## Provincia

# %%
print(df1.shape)
df1.head()
# Out:
# (840, 15)
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# 0  2022          3     Buenos Aires           29985                27709
# 1  2022          3  Capital Federal             517                 5742
# 2  2022          3        Catamarca              71                  384
# 3  2022          3            Chaco             461                  987
# 4  2022          3           Chubut             109                 1444
#
#    + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  \
# 0             290315              297915               267044
# 1              34371               67829                51946
# 2               3107                5389                 5099
# 3              16782               18938                 8049
# 4              45707               30940                34682
#
#    + 20 Mbps - 30 Mbps  + 30 Mbps   OTROS  Banda ancha fija  Dial up    Total  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           840 non-null    int32
#  1   Trimestre                     840 non-null    int32
#  2   Provincia                     840 non-null    object
#  3   HASTA 512 kbps                840 non-null    int32
#  4   + 512 Kbps - 1 Mbps           840 non-null    int32
#  5   + 1 Mbps - 6 Mbps             840 non-null    int32
#  6   + 6 Mbps - 10 Mbps            840 non-null    int32
#  7   + 10 Mbps - 20 Mbps           840 non-null    int32
#  8   + 20 Mbps - 30 Mbps           840 non-null    int32
#  9   + 30 Mbps                     840 non-null    int32
#  10  OTROS                         840 non-null    int32
#  11  Banda ancha fija              840 non-null    int32
#  12  Dial up                       840 non-null    int32
# ...

# %%
df1.describe()
# Out:
#                Año   Trimestre  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# count   840.000000  840.000000      840.000000           840.000000
# mean   2017.885714    2.457143     2086.426190         10142.846429
# std       2.528745    1.105009    13615.218242         22262.822375
# min    2014.000000    1.000000        6.000000             0.000000
# 25%    2016.000000    1.000000       36.750000           307.000000
# 50%    2018.000000    2.000000      110.000000          2730.500000
# 75%    2020.000000    3.000000      568.000000          8130.250000
# max    2022.000000    4.000000   238920.000000        171244.000000
#
#        + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  \
# count       8.400000e+02          840.000000           840.000000
# mean        1.509700e+05        37396.558333         38292.270238
# std         3.481538e+05        65406.204913         93996.489735
# min         2.842000e+03            0.000000             0.000000
# ...

# %%
tipo_texto_df1 = df1.select_dtypes(include=["object"]).columns
tipo_texto_df1 = df1[tipo_texto_df1]
tipo_texto_df1.describe()
# Out:
#            Provincia
# count            840
# unique            24
# top     Buenos Aires
# freq              35

# %%
df1.isnull().sum()
# Out:
# Año                             0
# Trimestre                       0
# Provincia                       0
# HASTA 512 kbps                  0
# + 512 Kbps - 1 Mbps             0
# + 1 Mbps - 6 Mbps               0
# + 6 Mbps - 10 Mbps              0
# + 10 Mbps - 20 Mbps             0
# + 20 Mbps - 30 Mbps             0
# + 30 Mbps                       0
# OTROS                           0
# Banda ancha fija                0
# Dial up                         0
# Total                           0
# Accesos por cada 100 hogares    0
# dtype: int64

# %%
df1.hist(bins = 50, figsize= (20,15))
plt.show()

# %% [markdown]
# ## Localidad

# %%
print(df6.shape)
df6.head()
# Out:
# (3098, 14)
#       Provincia     Partido          Localidad Link Indec  HASTA 512 kbps  \
# 0  BUENOS AIRES  25 de Mayo         25 de Mayo    6854100               2
# 1  BUENOS AIRES  25 de Mayo    Agustín Mosconi    6854010               0
# 2  BUENOS AIRES  25 de Mayo          Del Valle    6854020               1
# 3  BUENOS AIRES  25 de Mayo          Ernestina    6854030               0
# 4  BUENOS AIRES  25 de Mayo  Gobernador Ugarte    6854040               0
#
#    + 512 Kbps - 2 Mbps  + 2 Kbps - 6 Mbps  + 6 Kbps - 13 Mbps  \
# 0                   19                403                4577
# 1                    0                 45                  13
# 2                    0                181                  10
# 3                    0                 66                   0
# 4                  106                 69                   5
#
#    + 13 Kbps - 20 Mbps  + 20 Kbps - 40 Mbps  + 40 Kbps - 60 Mbps  \
# 0                 1019                  307                    0
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3098 entries, 0 to 3097
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Provincia             3098 non-null   object
#  1   Partido               3098 non-null   object
#  2   Localidad             3098 non-null   object
#  3   Link Indec            3098 non-null   object
#  4   HASTA 512 kbps        3098 non-null   int64
#  5   + 512 Kbps - 2 Mbps   3098 non-null   int64
#  6   + 2 Kbps - 6 Mbps     3098 non-null   int64
#  7   + 6 Kbps - 13 Mbps    3098 non-null   int64
#  8   + 13 Kbps - 20 Mbps   3098 non-null   int64
#  9   + 20 Kbps - 40 Mbps   3098 non-null   int64
#  10  + 40 Kbps - 60 Mbps   3098 non-null   int64
#  11  + 60 Kbps - 80 Mbps   3098 non-null   int64
#  12  + 80 Kbps - 100 Mbps  3098 non-null   int64
#  13  Total                 3098 non-null   int64
# dtypes: int64(10), object(4)
# memory usage: 339.0+ KB

# %%
df6.describe()
# Out:
#        HASTA 512 kbps  + 512 Kbps - 2 Mbps  + 2 Kbps - 6 Mbps  \
# count     3098.000000          3098.000000        3098.000000
# mean       123.320852            60.700129         345.399613
# std       2310.201555           304.015129        1381.674571
# min       -601.000000             0.000000           0.000000
# 25%          0.000000             0.000000           0.000000
# 50%          0.000000             0.000000          26.000000
# 75%          2.000000            15.000000         207.000000
# max     105017.000000          7486.000000       34042.000000
#
#        + 6 Kbps - 13 Mbps  + 13 Kbps - 20 Mbps  + 20 Kbps - 40 Mbps  \
# count         3098.000000          3098.000000          3098.000000
# mean           439.485797           198.154939           431.130407
# std           2846.954995          1474.071500          2688.597630
# min              0.000000             0.000000             0.000000
# ...

# %%
tipo_texto_df6 = df6.select_dtypes(include=["object"]).columns
tipo_texto_df6 = df6[tipo_texto_df6]
tipo_texto_df6.describe()
# Out:
#            Provincia    Partido Localidad Link Indec
# count           3098       3098      3098       3098
# unique            24        432      2801       2679
# top     BUENOS AIRES  San Justo     Otros  Sin Datos
# freq             712         55        74         77

# %%
df6.isnull().sum()
# Out:
# Provincia               0
# Partido                 0
# Localidad               0
# Link Indec              0
# HASTA 512 kbps          0
# + 512 Kbps - 2 Mbps     0
# + 2 Kbps - 6 Mbps       0
# + 6 Kbps - 13 Mbps      0
# + 13 Kbps - 20 Mbps     0
# + 20 Kbps - 40 Mbps     0
# + 40 Kbps - 60 Mbps     0
# + 60 Kbps - 80 Mbps     0
# + 80 Kbps - 100 Mbps    0
# Total                   0
# dtype: int64

# %%
grafico_correlacion_mapadecalor(df6)

# %%
df6.hist(bins = 50, figsize= (20,15))
plt.show()

# %%
print(df7.shape)
df7.head()
# Out:
# (4312, 16)
#       Provincia       Partido      Localidad  Poblacion ADSL CABLEMODEM  \
# 0  BUENOS AIRES  Bahía Blanca  Villa Bordeau          0   --         --
# 1  BUENOS AIRES  Bahía Blanca   Villa Espora          0   --         --
# 2  BUENOS AIRES      Balcarce       Balcarce      38376   SI         SI
# 3  BUENOS AIRES      Balcarce      Los Pinos        337   --         --
# 4  BUENOS AIRES      Balcarce      Napaleofú        374   --         --
#
#   DIALUP FIBRAOPTICA SATELITAL WIRELESS TELEFONIAFIJA  3G  4G       link  \
# 0     --          --        --       --            --  SI  SI  6056020.0
# 1     --          --        --       --            --  --  --  6056020.0
# 2     SI          SI        --       SI            SI  SI  SI  6063010.0
# 3     --          --        --       SI            SI  --  --  6063020.0
# 4     --          SI        --       SI            SI  SI  SI  6063030.0
#
#              Latitud           Longitud
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4312 entries, 0 to 4311
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provincia      4312 non-null   object
#  1   Partido        4312 non-null   object
#  2   Localidad      4312 non-null   object
#  3   Poblacion      4312 non-null   int64
#  4   ADSL           4312 non-null   object
#  5   CABLEMODEM     4312 non-null   object
#  6   DIALUP         4312 non-null   object
#  7   FIBRAOPTICA    4312 non-null   object
#  8   SATELITAL      4312 non-null   object
#  9   WIRELESS       4312 non-null   object
#  10  TELEFONIAFIJA  4312 non-null   object
#  11  3G             4312 non-null   object
#  12  4G             4312 non-null   object
#  13  link           4300 non-null   float64
#  14  Latitud        4312 non-null   object
#  15  Longitud       4312 non-null   object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 539.1+ KB

# %%
df7.describe()
# Out:
#           Poblacion          link
# count  4.312000e+03  4.300000e+03
# mean   8.693093e+03  3.909872e+07
# std    3.821544e+04  2.939305e+07
# min    0.000000e+00  2.000010e+06
# 25%    1.160000e+02  1.009104e+07
# 50%    5.755000e+02  3.401053e+07
# 75%    3.202000e+03  6.612602e+07
# max    1.317298e+06  9.401402e+07

# %%
tipo_texto_df7 = df7.select_dtypes(include=["object"]).columns
tipo_texto_df7 = df7[tipo_texto_df7]
tipo_texto_df7.describe()
# Out:
#            Provincia       Partido  Localidad  ADSL CABLEMODEM DIALUP  \
# count           4312          4312       4312  4312       4312   4312
# unique            24           444       3912     2          2      2
# top     BUENOS AIRES  General Roca  San Pedro    --         --     --
# freq             901            85         12  3179       3436   3909
#
#        FIBRAOPTICA SATELITAL WIRELESS TELEFONIAFIJA    3G    4G  \
# count         4312      4312     4312          4312  4312  4312
# unique           2         2        2             2     2     2
# top             --        --       SI            SI    --    SI
# freq          2866      3233     2242          2162  2432  2574
#
#                   Latitud           Longitud
# count                4312               4312
# unique               4260               4259
# top     -28,5555816291232  -67,1592836516078
# freq                    4                  4

# %%
df7.isnull().sum()
# Out:
# Provincia         0
# Partido           0
# Localidad         0
# Poblacion         0
# ADSL              0
# CABLEMODEM        0
# DIALUP            0
# FIBRAOPTICA       0
# SATELITAL         0
# WIRELESS          0
# TELEFONIAFIJA     0
# 3G                0
# 4G                0
# link             12
# Latitud           0
# Longitud          0
# dtype: int64

# %%
df7.hist(bins = 50, figsize= (20,15))
plt.show()

# %%
print(df4.shape)
df4.head()
# Out:
# (3142, 13)
#       Provincia     Partido               Localidad Link Indec  ADSL  \
# 0  BUENOS AIRES  25 de Mayo              25 de Mayo    6854100   873
# 1  BUENOS AIRES  25 de Mayo               Del Valle    6854020   181
# 2  BUENOS AIRES  25 de Mayo       Gobernador Ugarte    6854040     0
# 3  BUENOS AIRES  25 de Mayo  Norberto de la Riestra    6854060     0
# 4  BUENOS AIRES  25 de Mayo        Lucas Monteverde    6854050     0
#
#    CABLEMODEM  DIAL UP  FIBRA OPTICA  OTROS  SATELITAL  WIMAX  WIRELESS  \
# 0        4704        0             2      0        975      0       664
# 1           0        0             0     10          1      0         0
# 2           0        0             0      0          0      0       181
# 3         782        0             6    167          0      0       327
# 4           0        0             0      0          0      0         6
#
#    Total general
# 0           7218
# 1            192
# 2            181
# 3           1282
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provincia      3142 non-null   object
#  1   Partido        3142 non-null   object
#  2   Localidad      3142 non-null   object
#  3   Link Indec     3142 non-null   object
#  4   ADSL           3142 non-null   int64
#  5   CABLEMODEM     3142 non-null   int64
#  6   DIAL UP        3142 non-null   int64
#  7   FIBRA OPTICA   3142 non-null   int64
#  8   OTROS          3142 non-null   int64
#  9   SATELITAL      3142 non-null   int64
#  10  WIMAX          3142 non-null   int64
#  11  WIRELESS       3142 non-null   int64
#  12  Total general  3142 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 319.2+ KB

# %%
df4.describe()
# Out:
#                 ADSL    CABLEMODEM      DIAL UP   FIBRA OPTICA         OTROS  \
# count    3142.000000  3.142000e+03  3142.000000    3142.000000   3142.000000
# mean      444.072884  1.919787e+03     3.958307     913.921388     69.207193
# std      3247.312984  2.368834e+04    44.704276    6213.194911    881.659067
# min         0.000000  0.000000e+00     0.000000       0.000000      0.000000
# 25%         0.000000  0.000000e+00     0.000000       0.000000      0.000000
# 50%         0.000000  0.000000e+00     0.000000       0.000000      0.000000
# 75%       113.750000  9.000000e+00     0.000000      57.750000      0.000000
# max    140791.000000  1.240125e+06  2145.000000  208950.000000  29585.000000
#
#          SATELITAL        WIMAX      WIRELESS  Total general
# count  3142.000000  3142.000000   3142.000000   3.142000e+03
# mean      1.030236     0.670592    177.310630   3.529958e+03
# std      17.535193    14.883203    685.352342   3.155495e+04
# ...

# %%
tipo_texto_df4 = df4.select_dtypes(include=["object"]).columns
tipo_texto_df4 = df4[tipo_texto_df4]
tipo_texto_df4.describe()
# Out:
#            Provincia       Partido Localidad Link Indec
# count           3142          3142      3142       3142
# unique            24           432      2850       2718
# top     BUENOS AIRES  General Roca     OTROS  Sin Datos
# freq             716            57        69         72

# %%
df4.isnull().sum()
# Out:
# Provincia        0
# Partido          0
# Localidad        0
# Link Indec       0
# ADSL             0
# CABLEMODEM       0
# DIAL UP          0
# FIBRA OPTICA     0
# OTROS            0
# SATELITAL        0
# WIMAX            0
# WIRELESS         0
# Total general    0
# dtype: int64

# %%
grafico_correlacion_mapadecalor(df4)

# %%
df4.hist(bins = 50, figsize= (20,15))
plt.show()
